# %%
#Session14_Project Assignment code
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline
# Reading the content as a dataframe
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
# Reading the content as a dataframe
df1 = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
# Getting the meta-data using the info() method
df.info()
print("\n")
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# ...

# %%
#  We can get the rownames using the index and the values can be accessed via ".values" method
df.index.values
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
df1.index.values
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %%
# Renaming Indicator to Indicator_id. Setting inplace=True will modify the existing dataframe
df.rename(columns={'Indicator':'Indicator_id'},inplace=True)
df.head(2)
# Out:
#                        Indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
# Renaming columns
df.rename(columns={'PUBLISH STATES':'Publication Status','WHO region':'WHO Region'},inplace=True)
df.head(2)
# Out:
#                        Indicator_id Publication Status  Year WHO Region  \
# 0  Life expectancy at birth (years)          Published  1990     Europe
# 1  Life expectancy at birth (years)          Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
# Sorting based on the values of year
df.sort_values('Year')
# Out:
#                                          Indicator_id Publication Status  \
# 0                    Life expectancy at birth (years)          Published
# 1270                 Life expectancy at birth (years)          Published
# 3193                 Life expectancy at birth (years)          Published
# 3194                 Life expectancy at birth (years)          Published
# 3197                Life expectancy at age 60 (years)          Published
# 1264                 Life expectancy at birth (years)          Published
# 3199                Life expectancy at age 60 (years)          Published
# 1262                Life expectancy at age 60 (years)          Published
# 1259                 Life expectancy at birth (years)          Published
# 3203                Life expectancy at age 60 (years)          Published
# 1273                Life expectancy at age 60 (years)          Published
# 3204                 Life expectancy at birth (years)          Published
# ...

# %%
# Sorting based on values of multiple columns
df.sort_values(by=['Year','Indicator_id','WHO Region','Country','Publication Status'], ascending=True, na_position='last')
# Out:
#                            Indicator_id Publication Status  Year  \
# 2511  Life expectancy at age 60 (years)          Published  1990
# 3257  Life expectancy at age 60 (years)          Published  1990
# 3259  Life expectancy at age 60 (years)          Published  1990
# 686   Life expectancy at age 60 (years)          Published  1990
# 1519  Life expectancy at age 60 (years)          Published  1990
# 3110  Life expectancy at age 60 (years)          Published  1990
# 563   Life expectancy at age 60 (years)          Published  1990
# 973   Life expectancy at age 60 (years)          Published  1990
# 1400  Life expectancy at age 60 (years)          Published  1990
# 2482  Life expectancy at age 60 (years)          Published  1990
# 4341  Life expectancy at age 60 (years)          Published  1990
# 4343  Life expectancy at age 60 (years)          Published  1990
# 158   Life expectancy at age 60 (years)          Published  1990
# ...

# %%
# Getting the list of columns using list function
cols = list(df)
# Modifying the order of columns in the datframe
df[['Country',
 'Indicator_id',
 'Publication Status',
 'Year',
 'WHO Region',
 'World Bank income group',
 'Sex',
 'Display Value',
 'Numeric',
 'Low',
 'High',
 'Comments']]
df.head(5)
# Out:
#                         Indicator_id Publication Status  Year  \
# 0   Life expectancy at birth (years)          Published  1990
# 1   Life expectancy at birth (years)          Published  2000
# 2  Life expectancy at age 60 (years)          Published  2012
# 3  Life expectancy at age 60 (years)          Published  2000
# 4   Life expectancy at birth (years)          Published  2012
#
#               WHO Region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# ...

# %%
# Getting values of a specific column
Country_values = df['WHO Region'].values
Country_values
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'],
#       dtype=object)

# %%
# Using the iloc() method and obtaining the specific rows using indices
df.iloc[[11,24,37]]
# Out:
#                          Indicator_id Publication Status  Year  \
# 11   Life expectancy at birth (years)          Published  2012
# 24  Life expectancy at age 60 (years)          Published  2012
# 37  Life expectancy at age 60 (years)          Published  2012
#
#          WHO Region World Bank income group            Country     Sex  \
# 11           Europe             High-income            Austria  Female
# 24  Western Pacific             High-income  Brunei Darussalam  Female
# 37           Europe             High-income             Cyprus  Female
#
#     Display Value  Numeric  Low  High  Comments
# 11             83     83.0  NaN   NaN       NaN
# 24             21     21.0  NaN   NaN       NaN
# 37             26     26.0  NaN   NaN       NaN

# %%
# Using isin() method to get the rows (Boolean value) and using ~ to perform a negation operation
Unwanted_rows = df.index.isin([5,12,23,56]) 
df[~Unwanted_rows].head()
# Out:
#                         Indicator_id Publication Status  Year  \
# 0   Life expectancy at birth (years)          Published  1990
# 1   Life expectancy at birth (years)          Published  2000
# 2  Life expectancy at age 60 (years)          Published  2012
# 3  Life expectancy at age 60 (years)          Published  2000
# 4   Life expectancy at birth (years)          Published  2012
#
#               WHO Region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# ...

# %%
# Reading the datasets
users = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
sessions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv' )
products = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv' )
transactions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
# Converting the object datatype to datetime datatype - To acheive NaT result
users['Registered'] = pd.to_datetime(users['Registered'])
users['Cancelled'] = pd.to_datetime(users['Cancelled'])
users.head()
# Out:
#    UserID      User  Gender Registered  Cancelled
# 0       1   Charles    male 2012-12-21        NaT
# 1       2     Pedro    male 2010-08-01 2010-08-08
# 2       3  Caroline  female 2012-10-23 2016-06-07
# 3       4   Brielle  female 2013-07-17        NaT
# 4       5  Benjamin    male 2010-11-25        NaT

# %%
# Converting the object datatype to datetime datatype - To acheive NaT result
sessions['SessionDate'] = pd.to_datetime(sessions['SessionDate'])
sessions.head()
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %%
transactions.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %%
# importing the necessary packages and mapping the sqldf function as a global variable (pysqldf) 
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import sqlite3 as db
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

# %%
# Performing a left join to keep all rows of transactions and matching rows from users
transactions.merge(users,on='UserID',how='left')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender Registered  Cancelled
# 0     NaN        NaT        NaT
# 1  female 2012-10-23 2016-06-07
# 2  female 2012-10-23 2016-06-07
# 3    male 2012-12-21        NaT
# ...

# %%
# Using sub query and acheiving the result
# t.* alias will pick all rows from transactions and sub query will imply the condition. 
# 'Or' condition is used to consider the null values as well
pysqldf("select t.* from transactions t where t.UserID not in (select UserID from users) or t.UserID is null;")
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              8      2014-04-24     NaN          2         3
# 2              9      2015-04-24     7.0          4         3

# %%
# Using the merge concept to acheive the result.
# Concept is like to full join and then a left join => concat and then drop the duplicates
trans_users = pd.concat([pd.merge(users,transactions,left_on='UserID',right_on='UserID',how='outer'),
           pd.merge(users,transactions,left_on='UserID',right_on='UserID',how='left')]).drop_duplicates(keep=False)
# Dropping the unwanted columns from the dataframe
trans_users.drop(['Gender','User','Registered','Cancelled'],axis=1,inplace=True)
# Obtaining the result in the desired format
trans_users[['TransactionID','TransactionDate','UserID','ProductID','Quantity']]
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity
# 9             1.0      2010-08-21     7.0        2.0       1.0
# 10            9.0      2015-04-24     7.0        4.0       3.0
# 11            8.0      2014-04-24     NaN        2.0       3.0

# %%
# Performing a self join using the UserId column on the same transactions dataframe
transactions.merge(users,on='UserID',how='inner')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender Registered  Cancelled
# 0  female 2012-10-23 2016-06-07
# 1  female 2012-10-23 2016-06-07
# 2  female 2012-10-23 2016-06-07
# 3  female 2012-10-23 2016-06-07
# 4    male 2012-12-21        NaT
# 5    male 2010-08-01 2010-08-08
# 6    male 2010-08-01 2010-08-08

# %%
# Performing a full outer join on transactions and users dataframes
transactions.merge(users,on='UserID',how='outer')
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
# ...

# %%
# Join to get the sessions that occured on the same day using SQL query 
pysqldf("select u.*,s.SessionID,s.SessionDate from users u join sessions s on u.Registered = s.SessionDate;")
# Out:
#    UserID      User  Gender                  Registered  \
# 0       1   Charles    male  2012-12-21 00:00:00.000000
# 1       2     Pedro    male  2010-08-01 00:00:00.000000
# 2       3  Caroline  female  2012-10-23 00:00:00.000000
# 3       4   Brielle  female  2013-07-17 00:00:00.000000
# 4       5  Benjamin    male  2010-11-25 00:00:00.000000
#
#                     Cancelled  SessionID                 SessionDate
# 0                        None          7  2012-12-21 00:00:00.000000
# 1  2010-08-08 00:00:00.000000          2  2010-08-01 00:00:00.000000
# 2  2016-06-07 00:00:00.000000          6  2012-10-23 00:00:00.000000
# 3                        None          9  2013-07-17 00:00:00.000000
# 4                        None          3  2010-11-25 00:00:00.000000

# %%
# Join to get the sessions that occured on the same day using pandas merge function
result = pd.merge(users,sessions,left_on="Registered",right_on="SessionDate")
# Renaming the overlapping column
result.rename(columns={'UserID_x':'UserID'},inplace=True)
# Obtaining the output in the desired format
print(result[['UserID','User','Gender','Registered','Cancelled','SessionID','SessionDate']],"\n")
# To acheive the expected result given, we are using the loc method and isin method to filter the result
Exp_Res = result[['UserID','User','Gender','Registered','Cancelled','SessionID','SessionDate']]
Exp_Res.loc[Exp_Res['UserID'].isin(['2','4'])]
# Out:
#    UserID      User  Gender Registered  Cancelled  SessionID SessionDate
# 0       1   Charles    male 2012-12-21        NaT          7  2012-12-21
# 1       2     Pedro    male 2010-08-01 2010-08-08          2  2010-08-01
# 2       3  Caroline  female 2012-10-23 2016-06-07          6  2012-10-23
# 3       4   Brielle  female 2013-07-17        NaT          9  2013-07-17
# 4       5  Benjamin    male 2010-11-25        NaT          3  2010-11-25
#    UserID     User  Gender Registered  Cancelled  SessionID SessionDate
# 1       2    Pedro    male 2010-08-01 2010-08-08          2  2010-08-01
# 3       4  Brielle  female 2013-07-17        NaT          9  2013-07-17

# %%
# Dataset with every possible (UserID, ProductID) pair (cross join)
user_id = users[['UserID']]
prod_id = transactions[['ProductID']]
pysqldf("select * from user_id cross join prod_id")
# Out:
#     UserID  ProductID
# 0        1          2
# 1        1          4
# 2        1          3
# 3        1          2
# 4        1          4
# 5        1          5
# 6        1          4
# 7        1          2
# 8        1          4
# 9        1          4
# 10       2          2
# 11       2          4
# 12       2          3
# 13       2          2
# 14       2          4
# 15       2          5
# 16       2          4
# 17       2          2
# 18       2          4
# 19       2          4
# 20       3          2
# 21       3          4
# 22       3          3
# 23       3          2
# 24       3          4
# 25       3          5
# 26       3          4
# 27       3          2
# 28       3          4
# 29       3          4
# 30       4          2
# 31       4          4
# 32       4          3
# 33       4          2
# 34       4          4
# 35       4          5
# 36       4          4
# 37       4          2
# 38       4          4
# 39       4          4
# ...

# %%
# The below steps are done to achieve the expected output given in the assignment where a cross join is made between two UserID columns
user_id = users[['UserID']]
prod_id1 = users[['UserID']]
# Just renaming it as a ProductID
prod_id1.rename(columns={'UserID':'ProductID'},inplace=True)

# %%
# Cross join operation
user_prod = pysqldf("select * from user_id cross join prod_id1")
user_prod
# Out:
#     UserID  ProductId
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %%
# Using a group by operation to get the quantity first
Quantity = transactions.groupby(['UserID','ProductID']).sum()
Quantity
# Out:
#                   TransactionID  Quantity
# UserID ProductID
# 1.0    2                      4         3
# 2.0    4                      5         1
#        5                      6         6
# 3.0    3                      3         1
#        4                     19         6
# 7.0    2                      1         1
#        4                      9         3

# %%
# Using a left join on the user_prod and quantity to get the actualy quantity purchased by each user 
user_quantity = pysqldf("select u.UserID,u.ProductId,q.Quantity from user_prod u left join Quantity q on u.UserID = q.UserID and u.ProductID = q.ProductID;")
# Filling the NaN values with 0.0 to get the expected output
user_quantity.fillna(0.0)
# Out:
#     UserID  ProductId  Quantity
# 0        1          1       0.0
# 1        1          2       3.0
# 2        1          3       0.0
# 3        1          4       0.0
# 4        1          5       0.0
# 5        2          1       0.0
# 6        2          2       0.0
# 7        2          3       0.0
# 8        2          4       1.0
# 9        2          5       6.0
# 10       3          1       0.0
# 11       3          2       0.0
# 12       3          3       1.0
# 13       3          4       6.0
# 14       3          5       0.0
# 15       4          1       0.0
# 16       4          2       0.0
# 17       4          3       0.0
# 18       4          4       0.0
# 19       4          5       0.0
# 20       5          1       0.0
# 21       5          2       0.0
# 22       5          3       0.0
# 23       5          4       0.0
# 24       5          5       0.0

# %%
# Dropping the NaN values from transaction
transactions_new = transactions.dropna()
# To get the possible pair of transactions, we do a full outer merge on the same transactins_new dataframe
pd.merge(transactions_new,transactions_new,left_on='UserID',right_on='UserID',how='outer')
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 9        2015-04-24     7.0            4           3
# 3                 9        2015-04-24     7.0            4           3
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 2        2011-05-26     3.0            4           1
# 7                 2        2011-05-26     3.0            4           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                3        2011-06-16     3.0            3           1
# 11                3        2011-06-16     3.0            3           1
# ...

# %%
# First occuring transaction for each user using a left merge on users and transactions.
# To drop the dduplicates, we use a subset on 'User' and keep the first occurence
data = pd.merge(users,transactions,on='UserID',how='left').drop_duplicates(subset='User',keep='first')
data
# Out:
#    UserID      User  Gender Registered  Cancelled  TransactionID  \
# 0       1   Charles    male 2012-12-21        NaT            4.0
# 1       2     Pedro    male 2010-08-01 2010-08-08            5.0
# 3       3  Caroline  female 2012-10-23 2016-06-07            2.0
# 7       4   Brielle  female 2013-07-17        NaT            NaN
# 8       5  Benjamin    male 2010-11-25        NaT            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 3      2011-05-26        4.0       1.0
# 7             NaN        NaN       NaN
# 8             NaN        NaN       NaN

# %%
# Getting list of columns
my_columns = list(data.columns) 
my_columns
# Out:
# ['UserID',
#  'User',
#  'Gender',
#  'Registered',
#  'Cancelled',
#  'TransactionID',
#  'TransactionDate',
#  'ProductID',
#  'Quantity']

# %%
# Dropping Nan values by defining a threshold value
list(data.dropna(thresh=int(data.shape[0] * .9), axis=1).columns)
# Out:
# ['UserID', 'User', 'Gender', 'Registered']

# %%
# Getting the list of columns in which null values are present
missing_info = list(data.columns[data.isnull().any()]) 
missing_info
# Out:
# ['Cancelled', 'TransactionID', 'TransactionDate', 'ProductID', 'Quantity']

# %%
# looping through the columns in which null is present and using shape() method to count the missing data
print("Count of missing data\n")
for col in missing_info:
    num_missing = data[data[col].isnull() == True].shape[0]
    print('number missing for column {}: {}'.format(col, num_missing))
# Out:
# Count of missing data
#
# number missing for column Cancelled: 3
# number missing for column TransactionID: 2
# number missing for column TransactionDate: 2
# number missing for column ProductID: 2
# number missing for column Quantity: 2

# %%
# Dividing the count by the total rows in the null value column = > we wil get the percentage of missing data 
print("Percentage of missing data\n")
for col in missing_info:
    percent_missing = data[data[col].isnull() == True].shape[0] / data.shape[0]
    print('percent missing for column {}: {} percent'.format( col, percent_missing))
# Out:
# Percentage of missing data
#
# percent missing for column Cancelled: 0.6 percent
# percent missing for column TransactionID: 0.4 percent
# percent missing for column TransactionDate: 0.4 percent
# percent missing for column ProductID: 0.4 percent
# percent missing for column Quantity: 0.4 percent
